# %% [markdown]
# <a href="https://colab.research.google.com/github/DesireeHc/EcuacionesDiferenciales/blob/main/EjerciciosTED2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl
import sympy as sym

# %%
#esto ese para que imprima las salidas de forma simbólica
sym.init_printing()

# %% [markdown]
# # Resolver los sistemas de ecuaciones siguientes:
# 4.1
# b)
# $$\frac{dx_1}{dt} = 2x_1+x_2$$
# $$\frac{dx_2}{dt}= 3x_1+2x_2$$

# %%
x, y=sym.symbols('x, y')

# %%
f=sym.Eq(2*x+y, 0)
g=sym.Eq(3*x+2*y, 0)

# %%
#me va a resolver el sistema (f,g) en (x, y)
sym.solve([f, g],(x,y))
# Out:
# {x: 0, y: 0}

# %%
A=sym.Matrix([[2, 1],[3,2]])

#calcula el determinante
A.det()

A.trace()

#los eigenvalues separados
r_1, r_2=A.eigenvals()
A.eigenvects()
def D(M):
    return M.trace()**2-4*M.det()

# %%
print("Det(A)=", A.det(), "Tr(A)=", A.trace(), "D(A)=", D(A))
# Out:
# Det(A)= 1 Tr(A)= 4 D(A)= 12

# %%
# The 2-dimensional linear system.
a, b, c, d = 2, 1, 3, 2
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]
    A= dx_dt
    print(dx_dt)

# %%
ts = np.linspace(0, -4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# c)
# $$\frac{dx_1}{dt} = x_2$$
# $$\frac{dx_2}{dt}= -4x_2$$
#
# matrix = [
#     [0, 1],
#     [0, -4]
# ]

# %%
x, y=sym.symbols('x, y')

# %%
f=sym.Eq(y, 0)
g=sym.Eq(-4*y, 0)

# %%
#me va a resolver el sistema (f,g) en (x, y)
sym.solve([f, g],(x,y))
# Out:
# {y: 0}

# %%
A=sym.Matrix([[0, 1],[-4,0]])

#calcula el determinante
A.det()

A.trace()

#los eigenvalues separados
r_1, r_2=A.eigenvals()
A.eigenvects()
def D(M):
    return M.trace()**2-4*M.det()

# %%
print("Det(A)=", A.det(), "Tr(A)=", A.trace(), "D(A)=", D(A))
# Out:
# Det(A)= 4 Tr(A)= 0 D(A)= -16

# %%
# The 2-dimensional linear system.
a, b, c, d = 0, 1, 0, -4
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]
    A= dx_dt
    print(dx_dt)

# %%
ts = np.linspace(0, -4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# d)
# $$\frac{dx_1}{dt} = 3x_1-6x_2$$
# $$\frac{dx_2}{dt}= x_1-2x_2$$
#
# matrix = [
#     [3, -6],
#     [1, -2]
# ]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl

# %%
# The 2-dimensional linear system.
a, b, c, d = 3, -6, 1, -2
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]
    A= dx_dt
    print(dx_dt)

# %%
def det(A):
  return[ad-bc]
def tr(A):
  return[a+d]
def D(A):
  return [tr(A)**2-4*det(A)]

# %%
print(det)
print(tr)
print(D)
# Out:
# <function det at 0x7c8924164670>
# <function tr at 0x7c89241645e0>
# <function D at 0x7c8924164940>

# %%
ts = np.linspace(0, -4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# 4.2. b)
# $$\frac{dx_1}{dt} = 5x_1+4x_2$$
# $$\frac{dx_2}{dt}= -x_1+x_2$$
#
# matrix = [
#     [5, 4],
#     [-1, 1]
# ]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl

# %%
# The 2-dimensional linear system.
a, b, c, d = 5, 4, -1, 1
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]
    A= dx_dt
    print(dx_dt)

# %%
def det(A):
  return[ad-bc]
def tr(A):
  return[a+d]
def D(A):
  return [tr(A)**2-4*det(A)]

# %%
print(det)
print(tr)
print(D)
# Out:
# <function det at 0x7c891de06440>
# <function tr at 0x7c891de06d40>
# <function D at 0x7c891de06dd0>

# %%
ts = np.linspace(0, -4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# 4.2. c)
# $$\frac{dx_1}{dt} = x_1-2x_2$$
# $$\frac{dx_2}{dt}= 2x_1+x_2$$
#
# matrix = [
#     [1, -2],
#     [2, 1]
# ]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl

# %%
# The 2-dimensional linear system.
a, b, c, d = 1,-2,2,1
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]
    A= dx_dt
    print(dx_dt)

# %%
print(det)
print(tr)
print(D)
# Out:
# <function det at 0x7c891de06440>
# <function tr at 0x7c891de06d40>
# <function D at 0x7c891de06dd0>

# %%
ts = np.linspace(0, -4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# 4.2. d)
# $$\frac{dx_1}{dt} = 3x_1-x_2$$
# $$\frac{dx_2}{dt}= 4x_1-x_2$$
#
# matrix = [
#     [3, -1],
#     [4, -1]
# ]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl

# %%
# The 2-dimensional linear system.
a, b, c, d = 3, -1, 4, -1
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]
    A= dx_dt
    print(dx_dt)

# %%
ts = np.linspace(0, -4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# 4.3. a)
# $$\frac{dx_1}{dt} = x_1+x_2+1$$
# $$\frac{dx_2}{dt}= -2x_1+4x_2+1$$
#
# matrix = [
#     [1, 1],
#     [-2, 4]
# ]+ vec(1, 1)

# %% [markdown]
# 4.3. b)
# $$\frac{dx_1}{dt} = -2x_1-x_2+9$$
# $$\frac{dx_2}{dt}= x_1-x_2+3$$
#
# matrix = [
#     [-2, -1],
#     [1, -1]
# ]+ vec(9, 3)

# %% [markdown]
# 4.3. c)
# $$\frac{dx_1}{dt} = x_1+x_2+2e^t$$
# $$\frac{dx_2}{dt}= -2x_1+4x_2+e^t$$
#
# matrix = [
#     [1, 1],
#     [-2, 4]
# ]+ vec(2e^t, e^t)

# %% [markdown]
# 4.4. a)
# $$\frac{dx_1}{dt} = 2x_1+\frac{1}{4} x_2$$
# $$\frac{dx_2}{dt}= 25x_1+2x_2$$ con (x(0), y(0))=(-1,10)
#
# Encontrar $$\lim_{t \to \infty} (x(t), y(t))$$, si éste existe
#
# $matrix = [
#     [2, 1/4],
#     [25, 2]
# ]$

# %% [markdown]
# b)
# $$\frac{dx_1}{dt} = \alpha x_1-\beta x_2$$
# $$\frac{dx_2}{dt}= \beta x_1+\alpha x_2$$
#
# Con condición inicial $x(0)=(1, 0)$ (suponer que $\beta \neq 0$)

# %% [markdown]
# c)
#
# $$ \dot X = \matrix[0 \  1 \ 0 \\ 0 \ 0 \ 1 \\ 0 \ -2 \ 2] $$
#
#
# con condiciones iniciales $$(x(0)=(10, 20, 30))$$

# %% [markdown]
# 4.5.
# Considere el problema con condiciones iniciales:
#
# $$\frac{dx_1}{dt} = x_2$$
# $$\frac{dx_2}{dt}= 2x_1-x_2$$
#
# con $x(0)=(3, 3w)$ donde w=cte en los reales

# %% [markdown]
# a) Resolver problema

# %% [markdown]
# b) ¿Cuánto debe valer w si deseamos que $$\lim_{t \to \infty} =0$$

# %% [markdown]
# 4.6 (Curva caternaria)
#
# Considere
# $$(\dot x, \dot y)= (a \ b \\ c \ d) (x, y)$$

# %% [markdown]
# a) Determinar condiciones sobre a, b, c y d tal que la matriz tenga como valores propios a $\lambda$ y $-\lambda$ con $\lambda$ en los reales
