# %% [markdown]
# <a href="https://colab.research.google.com/github/DesireeHc/EcuacionesDiferenciales/blob/main/Modelo_LV_para_din%C3%A1mica_gal%C3%A1ctica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Modelo de Lotka Volterra para dinámicas galácticas
#
# ## __Datos históricos, teóricos y contextuales__
#
# ###__¿Qué?__
#
# El modelo de Lotka-Volterra es un sistema de ecuaciones diferenciales no lineales de primer orden que describe la dinámica de sistemas biológicos, como ya lo vimos con anterioridad, este es el modelo adaptado a la dinámica de galaxias, el modelo puede describir __la interacción gravitacional entre dos galaxias__, como el gas interestelar y las estrellas, o entre distintas poblaciones estelares.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/2f/Hubble_ultra_deep_field.jpg" alt="Texto Alternativo" width="270" height="230">
#
#
# ###__¿Para qué?__
#
# Este modelo se utiliza para __estudiar y predecir__ la evolución de sistemas dinámicos complejos, en este caso, la interacción y evolución de galaxias bajo fuerzas gravitacionales. Permite __comprender patrones y comportamientos emergentes en el tiempo__, como la formación de estructuras, colisiones y fusiones de galaxias.
#
#
#
#
# ###__¿Quién?__
#
# El modelo original fue propuesto independientemente por Alfred J. Lotka en 1925 y Vito Volterra en 1926. En el contexto de la dinámica de galaxias, investigadores y astrofísicos han adaptado este modelo para estudiar las __interacciones galácticas, como aquellas observadas en grupos de galaxias o durante colisiones galácticas__.
#
#
#
# ### Contexto Histórico
#
#
#
# __Década de 1970 y 1980:__ Durante estas décadas, la astrofísica y la cosmología empezaron a _adoptar más formalmente métodos y modelos matemáticos para describir sistemas complejos_. La idea de usar modelos ecológicos como el de Lotka-Volterra se volvió más prominente debido a la búsqueda de analogías y modelos simplificados que pudieran describir procesos en sistemas astronómicos.
#
#
#
# ###Aplicación en Dinámica Galáctica:
# El modelo de Lotka-Volterra se adaptó para estudiar la _evolución de las galaxias_, particularmente en cómo el gas interestelar se convierte en estrellas y cómo las estrellas pueden influir en el gas interestelar. Esta adaptación se basa en la idea de que las estrellas y el gas pueden interactuar de manera similar a como lo hacen los depredadores y las presas en los ecosistemas.
#
#
#
# ##__Ecuaciones del Modelo__
#
# Las ecuaciones del modelo Lotka-Volterra adaptadas a la dinámica de galaxias pueden formularse de manera similar al modelo original, con ciertas adaptaciones para tener en cuenta las interacciones gravitacionales.
#
#
# __Componentes del Modelo:__
#
# * __Población de Gas Interestelar (G):__
#  Representa la __cantidad de gas disponible en la galaxia__, que puede ser convertido en estrellas a través del proceso de formación estelar.
#
#
#
# * __Población de Estrellas (S):__ Representa la __cantidad de estrellas en la galaxia__, que puede incrementar a medida que el gas se transforma en nuevas estrellas y decrecer por procesos como la muerte estelar y supernovas.
#
# ## Ecuaciones Diferenciales:
#
# Las ecuaciones de Lotka-Volterra para estas dos poblaciones pueden formularse de la siguiente manera:
#
# $$
# \begin{cases}
# \frac{dG}{dt}=\alpha G - βGS \\
# \frac{dS}{dt}= δGS - γS
# \end{cases}
# $$
#
# __donde:__
#
# * $\alpha$ es la tasa de suministro de gas interestelar (puede ser positivo si hay suministro constante o cero si no hay nuevo gas).
#
# *  $\beta$ es la tasa a la cual el gas se convierte en estrellas. Este parámetro describe la _eficiencia del proceso de formación estelar_. tipicamente vará entre 0.01 y 1.
#
# *  $\delta$ es la eficiencia de la formación estelar a partir del gas.Puede ser comparable a $\beta$ y varía entre 0.01 y 0.1.
#
# * $\gamma$ es la tasa de disminución de la población estelar debido a la muerte estelar y otros procesos. Dependiendo del tipo de galaxia y su historia de formación estelar, los valores de
# γ pueden variar, pero típicamente están en el rango de 0.01 a 0.1.
#
#
# ## Interpretación de las Ecuaciones
#
# $$\frac{dG}{dt}=\alpha G - βGS$$
#
# La primera ecuación indica que el cambio en la cantidad de gas ($G$) depende de una fuente de suministro $\alpha G$ y una pérdida debido a la formación de estrellas $\beta G S$.
#
#
# $$\frac{dS}{dt}= δGS - γS$$
#
# La segunda ecuación indica que el cambio en la cantidad de estrellas ($S$) aumenta con la formación de estrellas $\delta G S$ y disminuye con la muerte estelar $\gamma S$.
#
#
#
# ##Puntos de Equilibrio
#
# Para encontrar los puntos de equilibrio, se establecen $\frac{dG}{dt} = 0$ y $\frac{dS}{dt} = 0$, y se resuelven las ecuaciones resultantes.
#
# \begin{align*}
#     G(\alpha - \beta S) &= 0 \\
#     S(\delta G - \gamma) &= 0
# \end{align*}
#
# Los puntos críticos son:
#
# $(G,S)=(0,0)$
#
# Este punto representa un __estado en el que no hay gas ni estrellas__. Es un estado trivial y generalmente no es de interés en la dinámica galáctica real.
#
# $(G,S)=(\frac{γ}{δ}, \frac{α}{β})$
#
# Este punto representa un __equilibrio donde las cantidades de gas y estrellas son constantes__. La relación entre la tasa de suministro de gas y la tasa de formación estelar, así como la tasa de disminución de la población estelar, determina las cantidades equilibradas.
#
#
# ###Teoremas
#
# __Teorema (Existencia y Unicidad):__
#
# La existencia y unicidad de soluciones para sistemas de ecuaciones diferenciales ordinarias se pueden garantizar utilizando el _Teorema de Picard-Lindelöf_. Este teorema establece que __si las funciones en el sistema son localmente Lipschitz continuas, entonces existe una única solución que pasa por un punto inicial dado__.
#
# __Teorema (Cantidad Conservada):__
#
# Existe una cantidad conservada a lo largo de las trayectorias del sistema. Esta cantidad está dada por:
#
# $$
# H(G, S) = \alpha \ln S - \beta S + \gamma \ln G - \delta G
# $$
#
# __Teorema (Comportamiento Acotado):__
#
#  Las soluciones del sistema de ecuaciones diferenciales del modelo de Lotka-Volterra están acotadas y permanecen en el primer cuadrante del plano $(G,S)$ para
# t≥0, siempre que las condiciones iniciales $(𝐺_0,𝑆_0)$ estén en el primer cuadrante.

# %%
# Importamos las librerías necesarias
import sympy as sym  # Para cálculos simbólicos
import matplotlib.pyplot as plt  # Para gráficos
import numpy as np  # Para cálculos numéricos
from scipy.integrate import odeint  # Para integrar ecuaciones diferenciales ordinarias

# Definir símbolos y parámetros
G, S = sym.symbols('G S')
alpha, beta, delta, gamma = 0.5, 0.1, 0.3, 0.2  # Valores de ejemplo para los parámetros

# Definir las ecuaciones del modelo de Lotka-Volterra para dinámica galáctica
dG_dt = alpha * G - beta * G * S
dS_dt = delta * G * S - gamma * S

# Encontrar los puntos críticos
critical_points = sym.solve([dG_dt, dS_dt], (G, S))

# Matriz Jacobiana
jacobi_matrix = sym.Matrix([[dG_dt.diff(var) for var in (G, S)],
                            [dS_dt.diff(var) for var in (G, S)]])

# Función discriminante
def discriminant(J):
    return J.trace()**2 - 4 * J.det()

# Función para determinar el tipo de punto fijo
def tipo(matrix):
    t = matrix.trace()
    d = matrix.det()
    disc = discriminant(matrix)

    if t > 0 and d > 0 and disc > 0:
        return "Región I (Nodo inestable)"
    elif t > 0 and d > 0 and disc < 0:
        return "Región II (Foco inestable)"
    elif t < 0 and d > 0 and disc < 0:
        return "Región III (Foco estable)"
    elif t < 0 and d > 0 and disc > 0:
        return "Región IV (Nodo estable)"
    elif d < 0 and disc < 0:
        return "Región V (Silla de montar)"
    else:
        return "Degenerado"

# Clasificar la estabilidad del punto fijo
def clas(matrix):
    t = matrix.trace()
    d = matrix.det()

    if t < 0 and d > 0:
        return "El punto fijo es estable y atractivo"
    elif t <= 0 and d > 0:
        return "El punto fijo es estable"
    elif t > 0 and d < 0:
        return "El punto fijo es inestable"
    else:
        return "No tiene clasificación"

# Evaluación en puntos críticos y clasificación
print("Puntos críticos y su clasificación:")
for point in critical_points:
    J = jacobi_matrix.subs({G: point[0], S: point[1]})
    tr = J.trace()
    det = J.det()
    disc = discriminant(J)

    print(f"\nPunto crítico: {point}")
    print(f"Traza: {tr}")
    print(f"Determinante: {det}")
    print(f"Discriminante: {disc}")
    print(f"Tipo: {tipo(J)}")
    print(f"Clasificación: {clas(J)}")

# Retrato fase del modelo
def lotka_volterra_galactica(X, t, alpha, beta, delta, gamma):
    G, S = X
    dG_dt = alpha * G - beta * G * S
    dS_dt = delta * G * S - gamma * S
    return [dG_dt, dS_dt]

G_range = np.linspace(0, 10, 20)
S_range = np.linspace(0, 10, 20)
X, Y = np.meshgrid(G_range, S_range)
dG_dt_vals = np.array([[dG_dt.subs({G: G_val, S: S_val}) for G_val in G_range] for S_val in S_range], dtype=float)
dS_dt_vals = np.array([[dS_dt.subs({G: G_val, S: S_val}) for G_val in G_range] for S_val in S_range], dtype=float)

fig, ax = plt.subplots()
ax.streamplot(X, Y, dG_dt_vals, dS_dt_vals, density=1)
for point in critical_points:
    ax.plot(point[0], point[1], 'ro')
plt.xlabel('Gas Interestelar (G)')
plt.ylabel('Estrellas (S)')
plt.title('Retrato Fase del Modelo de Lotka-Volterra en Dinámica Galáctica')
plt.grid()
plt.show()

# Graficar trayectorias del sistema de Lotka-Volterra
def grafica(func):
    ts = np.linspace(0, 50, 1000)
    ic = np.linspace(1, 5, 4)
    for r in ic:
        for s in ic:
            x0 = [r, s]
            xs = odeint(func, x0, ts, args=(alpha, beta, delta, gamma))
            plt.plot(xs[:, 0], xs[:, 1], "r-")

    plt.xlabel('Gas Interestelar (G)', fontsize=10)
    plt.ylabel('Estrellas (S)', fontsize=10)
    plt.tick_params(labelsize=10)
    plt.xlim(0, 10)
    plt.ylim(0, 10)

    X, Y = np.mgrid[0:10:10j, 0:10:10j]
    u = alpha * X - beta * X * Y
    v = delta * X * Y - gamma * Y
    plt.quiver(X, Y, u, v, color='b')
    plt.show()

# Ejecutar la gráfica de trayectorias
grafica(lotka_volterra_galactica)
# Out:
# Puntos críticos y su clasificación:
#
# Punto crítico: (0.0, 0.0)
# Traza: 0.300000000000000
# Determinante: -0.100000000000000
# Discriminante: 0.490000000000000
# Tipo: Degenerado
# Clasificación: El punto fijo es inestable
#
# Punto crítico: (0.666666666666667, 5.00000000000000)
# Traza: -2.77555756156289E-17
# Determinante: 0.100000000000000
# Discriminante: -0.400000000000000
# Tipo: Región III (Foco estable)
# Clasificación: El punto fijo es estable y atractivo

# %% [markdown]
# ##Trayectorias y Soluciones en el Retrato Fase
#
# Las trayectorias en el retrato fase representan la evolución temporal del sistema en el espacio de fase
# (G,S). Cada trayectoria muestra cómo cambian las cantidades de gas y estrellas con el tiempo, partiendo de diferentes condiciones iniciales.
#
# ## Retrato Fase
# El retrato fase es una representación gráfica de todas las posibles trayectorias del sistema en el espacio de fase. Ayuda a visualizar la dinámica del sistema y la estabilidad de los puntos críticos.
#
# ##Interpretación de las Trayectorias
#
# ### Trayectorias Convergentes a (𝛾𝛿,𝛼𝛽):
#
# __Interpretación:__
#
#  Si las trayectorias convergen a este punto crítico, indica que el sistema tiende a un estado de equilibrio estable donde las cantidades de gas y estrellas son constantes.
#
# __Estabilidad:__ Un punto de equilibrio estable donde las trayectorias convergen es atractivo.
#
# ### Trayectorias Divergentes de
# (0,0)
#
# __Interpretación:__
#
#  Si las trayectorias divergen de
# (0,0), indica que cualquier pequeña cantidad de gas o estrellas hace que el sistema evolucione lejos del estado sin gas ni estrellas.
#
# __Estabilidad:__ Un punto de equilibrio inestable donde las trayectorias divergen es repulsivo.
#
# ###Trayectorias Cíclicas o Oscilatorias
#
#
# __Interpretación:__ Si las trayectorias son cíclicas, el sistema experimenta oscilaciones periódicas en las cantidades de gas y estrellas. Este comportamiento puede indicar interacciones complejas entre la formación estelar y la disminución estelar.
#
# __Estabilidad:__ Las oscilaciones periódicas pueden indicar un equilibrio marginalmente estable o un ciclo límite.

# %% [markdown]
# ## Aplicaciones y Limitaciones
#
# * __Formación y Evolución Estelar:__
#
# El modelo puede ser útil para estudiar la tasa de formación estelar en diferentes tipos de galaxias y cómo esta tasa se relaciona con la cantidad de gas disponible.
#
# * __Interacción entre Componentes Galácticos:__
#
# Ayuda a entender cómo las estrellas y el gas interestelar interactúan y afectan la evolución de la galaxia.
#
# * __Simplificaciones y Limitaciones:__
#
# El modelo de Lotka-Volterra es una simplificación y no captura todos los procesos complejos y feedbacks presentes en las galaxias, como la retroalimentación de supernovas, la influencia de la materia oscura y la interacción con otras galaxias.
#
#
# El uso del modelo Lotka-Volterra en dinámica galáctica proporciona una perspectiva matemática simple pero poderosa para __analizar las interacciones básicas entre diferentes componentes de una galaxia__. Aunque es una aproximación simplificada, puede ofrecer valiosas intuiciones sobre los procesos fundamentales que rigen la evolución de las galaxias.
#
# ##Referencias
#
# https://bufadora.astrosen.unam.mx/~leonel/cursos/galactica/leccion_galactica_01.pdf
#
# https://es.wikipedia.org/wiki/Ecuaciones_de_Lotka-Volterra
#
# https://www.academia.edu/12384742/Modelo_de_Lotka_Volterra
