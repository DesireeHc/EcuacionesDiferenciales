# %% [markdown]
# <a href="https://colab.research.google.com/github/DesireeHc/EcuacionesDiferenciales/blob/main/modelo_de_oferta_y_demanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modelo de oferta y demanda
#
#
#
# ## Datos Históricos, Teóricos y Contextuales
#
#
# ###¿Qué?
#
# El modelo de oferta y demanda tiene sus raíces en los __principios fundamentales de la economía__, que datan desde los tiempos de _Adam Smith, David Ricardo_ y otros economistas clásicos. Sin embargo, la formalización matemática mediante ecuaciones diferenciales específicas se desarrollaron más tarde en el __siglo XX__.
#
#
#  En el ámbito económico, las ecuaciones diferenciales que describen la oferta y la demanda son una __extensión del análisis de equilibrio general y parcial__. Economistas como Alfred Marshall y Leon Walras contribuyeron significativamente al desarrollo de la teoría del equilibrio de mercado, que es fundamental para entender el comportamiento de oferta y demanda en mercados competitivos.
#
# <img src="https://economipedia.com/wp-content/uploads/Alfred-Marshall-2.jpg" alt="Texto Alternativo" width="170" height="200">
#
# Alfred Marshall
#
#
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/ac/Portrait_of_L%C3%A9on_Walras_1862_extract.png" alt="Texto Alternativo" width="170" height="200">
#
# Leon Walra
#
#
#
# __Aplicación Global:__
#
#  Las ecuaciones diferenciales que modelan la oferta y la demanda se utilizan en todo el mundo para __analizar y predecir__ comportamientos de mercado, ajustes de precios, políticas económicas y otras decisiones estratégicas.
#
#
# La aplicación del modelo de oferta y demanda, es global y fundamental en el análisis económico contemporáneo, influenciando políticas y decisiones en diversos mercados y contextos geográficos.
#
#
# ###¿Para qué?
#
# Han sido utilizadas para estudiar y predecir __dinámicas de mercado en economía__ además proporcionan un marco matemático para analizar y comprender los sistemas de oferta y demanda y ayudan a __tomar decisiones informadas en políticas económicas y empresariales__, como ajustes de precios, producción y políticas fiscales.
#
#
#
# ###¿Quién?
#
#  Han sido desarrolladas por economistas y matemáticos para entender los mecanismos de mercado.
#
#  Son estudiadas y utilizadas por académicos, economistas, analistas de mercado y empresas y se aplican en diferentes sectores económicos y empresariales para __mejorar la eficiencia y la toma de decisiones estratégicas__.
#
#
# <img src="https://laeconomia.com.mx/wp-content/uploads/oferta-y-demanda1.png" alt="Texto Alternativo" width="300" height="300">
#
#
#
# La curva de demanda muestra la cantidad de un bien o servicio que los consumidores están __dispuestos a comprar a diferentes precios__, manteniendo constantes otros factores como los ingresos, gustos y precios de bienes relacionados.
#
# La pendiente de la curva de demanda es negativa, lo que significa que, __a medida que el precio aumenta, la cantidad demandada disminuye.__
#
# La curva de oferta muestra la __cantidad de un bien o servicio que los productores están dispuestos a ofrecer a diferentes precios__, manteniendo constantes otros factores como los costos de producción, tecnología y precios de los insumos.
# La pendiente de la curva de oferta es positiva, lo que indica que, __a medida que el precio aumenta, los productores están dispuestos a ofrecer más cantidad del bien o servicio.__
#
# \
# ##Modelo
#
# Sea $p = P(t)$ la __función precio de un bien__ en el tiempo y $Q(t)$ es la __cantidad del bien__ en el tiempo $𝑡$. El número de
# unidades del bien que _desean los consumidores_ por unidad de tiempo, en
# cualquier tiempo $t$ se llama __demanda__ y se denota por $D = D(t)$. Esta demanda además de depender del precio $p$ en cualquier tiempo $t$, también depende de la dirección en la cual los consumidores creen que tomarán los precios, esto es, la __tasa de cambio del precio__ $P’(t)$. En matemáticas, la dependencia de $D(t)$, $P(t)$, y de $P’(t)$ se puede escribir como:
#
# $$D=f(p(t),p(t))$$
#
# Por tanto, $S$ es la función de oferta.
#
#
# Para que las anteriores consideraciones tengan sentido, se debe asumir
# lo siguiente:
#
# __a) Economía competitiva y libre.__
#
#  Es decir, que los consumidores y
# productores compiten para determinar los precios.
#
# __b) No hay demora en el suministro.__
#
#  En la ecuación se asume que los
# productores usan una tasa de cambio del precio en el tiempo, esto para
# decidir sobre la oferta disponible. Esto es una aproximación a
# la realidad, puesto que en la práctica hay una __demora entre el tiempo
# de producción real y el mercadeo al consumidor__. En tal caso se reemplazaría por:
#
# $$S=(g(p(t-T), p'(t-T))$$
#
# Sin embargo, se tomará con la suposición inicial.
#
# __c) No se consideran los precios de otros bienes.__
#
#  Los precios de otros bienes en el mercado no se toman en cuenta.
#
# __d) Los precios, demanda y oferta son continuos.__
#
#  Los precios toman valores discretos, pero en la práctica, se pueden __aproximar__ con un buen grado de precisión adoptando __valores continuos.__
#
# ##Ecuaciones del Modelo
#
# Las ecuaciones diferenciales representan un __modelo clásico de oferta y demanda__ donde $x$ representa la oferta y $y$ la demanda. Las ecuaciones describen cómo la oferta y la demanda cambian en función del tiempo y de las interacciones entre ellas.
#
# El modelo clásico de oferta y demanda se puede representar por las siguientes ecuaciones diferenciales:
#
# $$
# \begin{cases}
# \frac{dx}{dt}=αx−βxy \\
# \frac{dy}{dt}=−γy+δxy
# \end{cases}
# $$
#
# Donde:
# * x representa la (oferta).
# * y representa la (demanda).
# * α,β,γ,δ son __parámetros positivos__ que representan tasas de crecimiento y tasas de interacción entre las poblaciones.
#
# ### Interpretación de las ecuaciones
#
# 1.  La tasa de cambio de la oferta con respecto al tiempo $\frac{dx}{dt}$ se expresa como:
#
#  $$\frac{dx}{dt} = \alpha x - \beta xy$$
#
# Donde:
# * $\alpha$ representa la tasa de crecimiento natural de la oferta (en ausencia de demanda).
# * $\beta$ mide cómo la demanda afecta la oferta (por ejemplo, si la demanda es alta, la oferta puede disminuir).
#
#
# 2. La tasa de cambio de la demanda con respecto al tiempo $\frac{dy}{dt}$ se expresa como:
#
# $$\frac{dy}{dt} = -\gamma y + \delta xy$$
#
# Donde:
#
# * $\gamma$ representa la tasa de decrecimiento natural de la demanda.
# * $\delta$ mide cómo la oferta afecta la demanda (por ejemplo, si la oferta es alta, la demanda puede disminuir, cómo  la cantidad demandada aumenta debido a factores como el crecimiento de la población, cambios en el gusto de los consumidores, entre otros).
#
# Estas ecuaciones capturan la dinámica entre la oferta y la demanda en un mercado. El equilibrio se alcanza cuando las tasas de cambio de ambas son iguales, lo que determina el precio y la cantidad de equilibrio.
# Esto da lugar a los puntos críticos:
#
# ### Puntos Críticos y su Clasificación
# __Puntos Críticos:__
#
# Los puntos críticos son aquellos donde las tasas de cambio de $x$ y $y$ son cero simultáneamente. En este modelo, los puntos críticos se calculan resolviendo:
#
#
# $$αx−βxy=0$$
# $$−γy+δxy=0$$
#
# Así, los puntos críticos para este modelo son:
#
# * $(0,0)$
#
# Esto indica que no hay demanda ni oferta del bien en el mercado.
#
# * $(0,\frac{γ}{δ})$
#
# Esto significa que no hay demanda del bien, pero hay una oferta específica en el mercado.
#
# * $(\frac{α}{β},0)$
#
# Esto indica que hay demanda específica del bien, pero no hay oferta correspondiente en el mercado.
#
# * $(\frac{𝛾}{𝛿},\frac{𝛼}{𝛽})$
#
# Esto indica que hay un equilibrio en el mercado donde la cantidad demandada y la cantidad ofrecida son iguales.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Teoremas
#
# Este modelo clásico de oferta y demanda en economía se fundamenta en varios principios y teoremas importantes que sustentan su análisis y predicciones:
#
#
# * __Ley de la demanda:__ Esta ley establece que,  manteniendo todo lo demás constante, __la cantidad demandada de un bien disminuye cuando su precio aumenta, y viceversa__.
#
# <img src="https://angelacastaneda.net/wp-content/uploads/2023/06/La-Demanda_Angela-Castaneda-1-1024x576.jpg" alt="Texto Alternativo" width="300" height="200">
#
#
#
#
# * __Ley de la oferta:__ Esta ley indica que, la __cantidad ofrecida de un bien aumenta cuando su precio aumenta, y disminuye cuando su precio disminuye__. Es el principio básico que describe la relación positiva entre el precio de un bien y la cantidad que los productores están dispuestos a ofrecer.
#
# <img src="https://angelacastaneda.net/wp-content/uploads/2023/06/La-Oferta_Angela-Castaneda-1-1024x576.jpg" alt="Texto Alternativo" width="300" height="200">
#
#
#
#
# * __Equilibrio de mercado:__ Este teorema establece que en un mercado competitivo y libre de restricciones, __el precio y la cantidad de un bien se establecen en el punto donde la cantidad demandada es igual a la cantidad ofrecida__. Es decir, donde las curvas de oferta y demanda se intersectan.
#
#
#
#
#
# * __Teorema de la mano invisible de Adam Smith:__  Sugiere que los individuos que buscan maximizar su propio beneficio económico (en un mercado competitivo) de manera indirecta __promueven el bienestar general de la sociedad__ a través del mecanismo de precios y el intercambio voluntario.
#
#
#
# * __Teorema de la eficiencia de Pareto:__ Este teorema indica que en un mercado competitivo, el equilibrio de mercado es eficiente en el sentido de Pareto, lo que significa que __no es posible mejorar la situación de un individuo sin empeorar la de otro__. En otras palabras, el equilibrio maximiza el excedente total del consumidor y el productor.
#
#
#
#
# Estos teoremas y principios proporcionan __la base teórica y conceptual__ para entender cómo funcionan los mercados en el modelo de oferta y demanda

# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# Definir símbolos y parámetros
x, y = sym.symbols('x y')
alpha, beta, gamma, delta = 1, 0.5, 1.5, 0.8

# Definir las ecuaciones del modelo de oferta y demanda
dx_dt = alpha * x - beta * x * y
dy_dt = -gamma * y + delta * x * y

# Resolver las ecuaciones diferenciales ordinarias para encontrar los puntos críticos
critical_points = sym.solve([dx_dt, dy_dt], (x, y))

# Matriz Jacobiana
jacobi_matrix = sym.Matrix([[dx_dt.diff(var) for var in (x, y)],
                            [dy_dt.diff(var) for var in (x, y)]])

# Función discriminante
def discriminant(J):
    return J.trace()**2 - 4 * J.det()

# Función para determinar el tipo de punto fijo
def tipo(matrix):
    t = matrix.trace()
    d = matrix.det()
    disc = discriminant(matrix)

    if t > 0 and d > 0 and disc > 0:
        return "Región I (Nodo inestable)"
    elif t > 0 and d > 0 and disc < 0:
        return "Región II (Foco inestable)"
    elif t < 0 and d > 0 and disc < 0:
        return "Región III (Foco estable)"
    elif t < 0 and d > 0 and disc > 0:
        return "Región IV (Nodo estable)"
    elif d < 0 and disc < 0:
        return "Región V (Silla de montar)"
    else:
        return "Degenerado"

# Clasificar la estabilidad del punto fijo
def clas(matrix):
    t = matrix.trace()
    d = matrix.det()

    if t < 0 and d > 0:
        return "El punto fijo es estable y atractivo"
    elif t <= 0 and d > 0:
        return "El punto fijo es estable"
    elif t > 0 and d < 0:
        return "El punto fijo es inestable"
    else:
        return "No tiene clasificación"

# Evaluación en puntos críticos y clasificación
print("Puntos críticos y su clasificación:")
for point in critical_points:
    J = jacobi_matrix.subs({x: point[0], y: point[1]})
    tr = J.trace()
    det = J.det()
    disc = discriminant(J)

    print(f"\nPunto crítico: {point}")
    print(f"Traza: {tr}")
    print(f"Determinante: {det}")
    print(f"Discriminante: {disc}")
    print(f"Tipo: {tipo(J)}")
    print(f"Clasificación: {clas(J)}")

# Retrato fase del modelo de oferta y demanda
def oferta_demanda_model(X, t, alpha, beta, gamma, delta):
    x, y = X
    dx_dt = alpha * x - beta * x * y
    dy_dt = -gamma * y + delta * x * y
    return [dx_dt, dy_dt]

# Definir el rango de valores para las gráficas
x_range = np.linspace(0, 12, 100)
y_range = np.linspace(0, 12, 100)
X, Y = np.meshgrid(x_range, y_range)
dX_dt = alpha * X - beta * X * Y
dY_dt = -gamma * Y + delta * X * Y

# Generar el retrato fase
fig, ax = plt.subplots()
ax.streamplot(X, Y, dX_dt, dY_dt, density=1)
for point in critical_points:
    ax.plot(float(point[0]), float(point[1]), 'ro')
plt.xlabel('Oferta(x)')
plt.ylabel('Demanda (y)')
plt.title('Retrato Fase del Modelo de Oferta y Demanda')
plt.xlim(0, 12)
plt.ylim(0, 12)
plt.grid()
plt.show()

# Graficar trayectorias del modelo de oferta y demanda
def grafica(func):
    ts = np.linspace(0, 50, 1000)
    ic = np.linspace(0.1, 10, 5)
    for x0 in ic:
        for y0 in ic:
            initial_conditions = [x0, y0]
            xs = odeint(func, initial_conditions, ts, args=(alpha, beta, gamma, delta))
            plt.plot(xs[:, 0], xs[:, 1], "r-")

    plt.xlabel('Oferta (x)', fontsize=10)
    plt.ylabel('Demanda (y)', fontsize=10)
    plt.tick_params(labelsize=10)
    plt.xlim(0, 12)
    plt.ylim(0, 12)

    X, Y = np.mgrid[0:12:10j, 0:12:10j]
    u = alpha * X - beta * X * Y
    v = -gamma * Y + delta * X * Y
    plt.quiver(X, Y, u, v, color='b')
    for point in critical_points:
        plt.plot(float(point[0]), float(point[1]), 'ro')
    plt.show()

# Ejecutar la gráfica de trayectorias
grafica(oferta_demanda_model)
# Out:
# Puntos críticos y su clasificación:
#
# Punto crítico: (0.0, 0.0)
# Traza: -0.500000000000000
# Determinante: -1.50000000000000
# Discriminante: 6.25000000000000
# Tipo: Degenerado
# Clasificación: No tiene clasificación
#
# Punto crítico: (1.87500000000000, 2.00000000000000)
# Traza: 0
# Determinante: 1.50000000000000
# Discriminante: -6.00000000000000
# Tipo: Degenerado
# Clasificación: El punto fijo es estable

# %% [markdown]
# ## Interpretación del Retrato Fase
#
# __Puntos Críticos:__
#
#  Los puntos críticos representan los puntos de equilibrio del sistema, donde la oferta y la demanda se igualan.
#
# __Direcciones de las Trayectorias:__
#
#  Las flechas en el retrato fase indican la dirección en la que evolucionan las variables $𝑥$ y $𝑦$ a partir de condiciones iniciales dadas. Por ejemplo, si comenzamos con un __exceso de oferta__ (por encima del punto de equilibrio), las trayectorias nos muestran cómo la oferta disminuirá y la demanda aumentará hasta alcanzar nuevamente el equilibrio.
#
# __Estabilidad de los Puntos Críticos:__
#
#  La estabilidad de los puntos críticos se puede analizar observando cómo se comportan las trayectorias alrededor de estos puntos. Por ejemplo, un punto crítico es __estable__ si las trayectorias cercanas convergen hacia él con el tiempo, mientras que es __inestable__ si las trayectorias se alejan de él.
#
# ## Conclusiones del Modelo de Oferta y Demanda
#
#
# ###Ajuste Automático:
#
# El modelo sugiere que __los mercados tienden hacia el equilibrio de manera automática a través de los ajustes en los precios y las cantidades ofrecidas y demandadas__. Este proceso es fundamentalmente impulsado por las decisiones de los consumidores y los productores en respuesta a cambios en las condiciones económicas.
#
# ###Impacto de los Cambios en los Parámetros:
#
# Variaciones en los parámetros del modelo (tales como cambios en los costos de producción, impuestos, preferencias de los consumidores, etc.) pueden desplazar las curvas de oferta y demanda, afectando así el precio y la cantidad de equilibrio. El retrato fase puede mostrar cómo estos cambios __afectan las trayectorias de oferta y demanda en el tiempo__.
#
# ###Política Económica:
#
#  El modelo puede utilizarse para evaluar el __impacto de políticas económicas__, como subsidios, impuestos o regulaciones, sobre el equilibrio del mercado. Por ejemplo, un subsidio a la oferta podría desplazar la curva de oferta hacia la derecha, aumentando la cantidad ofrecida y reduciendo el precio de equilibrio.
#
# ### Análisis de Sensibilidad:
#  El análisis del retrato fase también permite evaluar la __sensibilidad del sistema a perturbaciones externas o cambios abruptos en las condiciones económicas__. Por ejemplo, cómo reaccionaría el mercado a una escasez repentina de materias primas o un cambio repentino en la demanda debido a factores externos.

# %% [markdown]
# ## Links de apoyo:
#
# https://dialnet.unirioja.es/descarga/articulo/3640667.pdf
#
# https://www.secmca.org/wp-content/uploads/2019/02/articulo93NOV2017.pdf
#
# https://eclass.uoa.gr/modules/document/file.php/MATH626/Morris%20W.%20Hirsch%2C%20Stephen%20Smale%20and%20Robert%20L.%20Devaney%20%28Auth.%29%20-%20Differential%20Equations%2C%20Dynamical%20Systems%2C%20and%20an%20Introduction%20to%20Chaos-Academic%20Press%20%282012%29.pdf
#
#
# https://crea.ujaen.es/bitstream/10953.1/11004/1/TFG_Guillermo_Vilches.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# Define the system of differential equations
def model(z, t, alpha, beta, gamma, delta):
    x, y = z
    dxdt = alpha * x - beta * x * y
    dydt = -gamma * y + delta * x * y
    return [dxdt, dydt]

# Parameters
alpha = 0.9
beta = 0.5
gamma = 0
delta = 10.8

# Initial conditions
z0 = [1.0, 1.0]

# Time vector
t = np.linspace(0, 10, 100)

# Solve the system of differential equations
z = odeint(model, z0, t, args=(alpha, beta, gamma, delta))

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(z[:, 0], z[:, 1], label='Trajectory')
plt.plot(0, 0, 'ro', label='(0, 0)')
plt.plot(0, gamma/delta, 'go', label='(0, γ/δ)')
plt.plot(alpha/beta, 0, 'bo', label='(α/β, 0)')
plt.plot(gamma/delta, alpha/beta, 'ko', label='(γ/δ, α/β)')
plt.xlabel('Cantidad ofrecida, y')
plt.ylabel('Cantidad demandada, x')
plt.title('Diagrama de fase del modelo de oferta y demanda')
plt.legend()
plt.grid(True)
plt.show()
