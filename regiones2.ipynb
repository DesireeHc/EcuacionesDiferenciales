# %% [markdown]
# <a href="https://colab.research.google.com/github/DesireeHc/EcuacionesDiferenciales/blob/main/regiones2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clasificación de sistemas lineales de 2x2**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl
import sympy as sym
#import matplotlib.patches as patches
#from matplotlib.patches import Text
import matplotlib.style as mplstyle
from PIL import Image

# %%
sym.init_printing()
x, y=sym.symbols('x, y')

# %%
A=sym.Matrix([[-3, 1],[1,-3]])
A.det()
A.trace()
A.eigenvals()
A.eigenvects()
# Out:
# ⎡⎛       ⎡⎡-1⎤⎤⎞  ⎛       ⎡⎡1⎤⎤⎞⎤
# ⎢⎜-4, 1, ⎢⎢  ⎥⎥⎟, ⎜-2, 1, ⎢⎢ ⎥⎥⎟⎥
# ⎣⎝       ⎣⎣1 ⎦⎦⎠  ⎝       ⎣⎣1⎦⎦⎠⎦

# %%
def D(M):
    return M.trace()**2-4*M.det()

# %%
#D0=A.trace()**2-4*A.det()
#def f():
 # return(x**2/4)

# %%
image_path = '/content/sample_data/imagenes/R1.png'
# Assuming your image path is 'path/to/your/image.png'


# Read the image file
try:
    image = Image.open(image_path)
except FileNotFoundError:
    print(f"Error: Image file not found at '{image_path}'.")
    exit()  # Exit if image is not found

# %%
image_path2 = '/content/sample_data/imagenes/R2.png'
# Assuming your image path is 'path/to/your/image.png'


# Read the image file
try:
    image2 = Image.open(image_path2)
except FileNotFoundError:
    print(f"Error: Image file not found at '{image_path2}'.")
    exit()  # Exit if image is not found

# %%
image_path3 = '/content/sample_data/imagenes/R3.png'
# Assuming your image path is 'path/to/your/image.png'


# Read the image file
try:
    image3 = Image.open(image_path3)
except FileNotFoundError:
    print(f"Error: Image file not found at '{image_path3}'.")
    exit()  # Exit if image is not found

# %%
image_path4 = '/content/sample_data/imagenes/R4.png'
# Assuming your image path is 'path/to/your/image.png'


# Read the image file
try:
    image4 = Image.open(image_path4)
except FileNotFoundError:
    print(f"Error: Image file not found at '{image_path4}'.")
    exit()  # Exit if image is not found

# %%
image_path5 = '/content/sample_data/imagenes/R5.png'
# Assuming your image path is 'path/to/your/image.png'


# Read the image file
try:
    image5 = Image.open(image_path5)
except FileNotFoundError:
    print(f"Error: Image file not found at '{image_path5}'.")
    exit()  # Exit if image is not found

# %%
def f(x):
  return x**2 / 4

# %%
x = np.arange(-7, 7, 0.1)  # Adjust the range as needed
y=f(x)
xmin=-8
xmax=8
ymin=-8
ymax=8

# Draw x-axis at y = 0
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.5)

# Draw y-axis at x = 0
plt.axvline(x=0, color='black', linestyle='--', linewidth=0.5)

# Annotate the axes intersection at (0, 0)
plt.text(0.2, 0.2, '0', fontsize=10, color='black')

plt.plot(x, y)
plt.xlabel('tr(A)')
plt.ylabel('det(A)')
plt.title('Grafica cuando  D(A)=0')
plt.grid(True)

plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)

plt.text(4, 1, "I", fontsize=12, fontstyle='italic', color='blue')
plt.text(3, 6.5, "II", fontsize=12, fontstyle='italic', color='blue')
plt.text(-3, 6.5, "III", fontsize=12, fontstyle='italic', color='blue')
plt.text(-4, 1, "IV", fontsize=12, fontstyle='italic', color='blue')
plt.text(-1, -3, "V", fontsize=12, fontstyle='italic', color='blue')

# Convert image to NumPy array
image_array = np.array(image)
# Adjust extent as needed (consider data range and image size)
extent = (4, 8, .5, 3)  # Example: match plot limits
# Add image with transparency
plt.imshow(image_array, alpha=1, extent=extent)



# Convert image to NumPy array
image_array = np.array(image2)
# Adjust
extent = (0.5, 3, 3.5, 6)
plt.imshow(image_array, alpha=1, extent=extent)

# Convert image to NumPy array
image_array = np.array(image3)
# Adjust
extent = (-0.5, -3, 3.5, 6)
plt.imshow(image_array, alpha=1, extent=extent)

# Convert image to NumPy array
image_array = np.array(image4)
# Adjust
extent = (-4, -8, .5, 3)
plt.imshow(image_array, alpha=1, extent=extent)

# Convert image to NumPy array
image_array = np.array(image5)
# Adjust
extent = (-3, 3, -3, -6)
plt.imshow(image_array, alpha=1, extent=extent)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Región I**
#
# det(A)>0, tr(A)>0 y D(A)>0

# %%
# The 2-dimensional linear system.
a, b, c, d = 2, 1, 1, 2
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]
    A= dx_dt
    print(dx_dt)

# %%
def det(A):
  return[ad-bc]
def tr(A):
  return[a+d]
def D(A):
  return [tr(A)**2-4*det(A)]

# %%
print(det)
print(tr)
print(D)
# Out:
# <function det at 0x7939e3045510>
# <function tr at 0x7939e30455a0>
# <function D at 0x7939e3045b40>

# %%
ts = np.linspace(0, -4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# **Región II**
#
# det(A)>0, tr(A)>0 y D(A)<0

# %%
# The 2-dimensional linear system.
a, b, c, d = 1, -1, 1, 1
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]

# %%
ts = np.linspace(0, -5, 100)
ic = np.linspace(-1, 1, 3)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# **Región III**
#
# det(A)>0, tr(A)<0 y D(A)<0

# %%
# The 2-dimensional linear system.
a, b, c, d = -1, -2, 1, -1
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]

# %%
ts = np.linspace(-1, 4, 150) # .  .  Se obtienen las lineas de solución (rojas)
ic = np.linspace(-1, 1, 3)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# **Región IV**
#
# det(A)>0, tr(A)<0 y D(A)>0

# %%
# The 2-dimensional linear system.
a, b, c, d = -3, -1, -1, -3
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]

# %%
ts = np.linspace(0, 4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.

plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %% [markdown]
# **Región V**
#
# det(A)>0, tr(A)>0 y D(A)<0

# %%
# The 2-dimensional linear system.
a, b, c, d = -1, -1, -1, 1
def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]

# %%
ts = np.linspace(-1, 5, 150) # ts paso del tiempo, lo que sucede con el tiempo. Se obtienen las lineas de solución (rojas)
ic = np.linspace(1, -1, 4) #condiciones iniciales (r, s) 4, genera las trayectorias para cada par de valores
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")# Label the axes and set fontsizes.


plt.xlabel('x', fontsize=15)  #coloca el nombre y tamaño del cuadrante x
plt.ylabel('y', fontsize=15) #coloca el nombre y tamaño del cuadrante y
plt.tick_params(labelsize=10) #tamaño de parámetros
plt.xlim(-1, 1)
plt.ylim(-1, 1)
X,Y = np.mgrid[-1:1:16j, -1:1:16j] #de donde a donde van la flechas, y cuantas flechas son
u = a*X + b*Y
v = c*X + d*Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()

# %%
# The 2-dimensional nonlinear system.
def dx_dt(x, t):
    return [x[1], x[0] * (1 - x[0]**2) + x[1]]

# %%
# Trajectories in forward time.
ts = np.linspace(0, 10, 500)
ic = np.linspace(-3, 3, 6)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")
# Trajectories in backward time.
ts = np.linspace(0, -10, 500)
ic = np.linspace(-3, 3, 6)
for r in ic:
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:,0], xs[:,1], "r-")
# Label the axes and set fontsizes.
plt.xlabel("x", fontsize=15)
plt.ylabel("y", fontsize=15)
plt.tick_params(labelsize=15)
plt.xlim(-3, 3)
plt.ylim(-3, 3);
# Plot the vectorfield.
X, Y = np.mgrid[-3:3:20j, -3:3:20j]
u=Y
v=X * (1 - X**2) + Y
pl.quiver(X, Y, u, v, color = 'b')
plt.show()
